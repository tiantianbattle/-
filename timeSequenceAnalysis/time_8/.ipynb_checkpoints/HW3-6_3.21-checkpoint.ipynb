# %% [markdown]
# # 某地区连续74年的谷物产量
#
# ## table3.21.csv

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.tsa.api as smt
from statsmodels.stats.diagnostic import acorr_ljungbox as lb_test

# %% [markdown]
# ## statsmodels自帶的畫ACF的函數

# %%
def drawts(y,pname):
    ##draw ax
    fig = plt.figure(figsize=(10,8))
    ts_ax=plt.subplot2grid((2,2),(0,0),colspan=2)
    acf_ax=plt.subplot2grid((2,2),(1,0))
    pacf_ax=plt.subplot2grid((2,2),(1,1))
    ##draw plot
    ts_ax.plot(y,'*-')
    ts_ax.set_title('Time Series Analysis Plots')
    smt.graphics.plot_acf(y,lags=None,ax=acf_ax,alpha=0.05) ##2sigma
    smt.graphics.plot_pacf(y,lags=None,ax=pacf_ax,alpha=0.05)  ##2sigma
    #plt.savefig('%s.jpg'%pname,dpi=256)
    plt.show()
    plt.close()

# %% [markdown]
# ## statsmodels自帶的LB test

# %%
def purerandtest(y):
    a,b=lb_test(y,lags=None,boxpierce=False)
    LB_purerand=pd.DataFrame(np.c_[a,b],columns=['LB','Pvalue'])
    LB_purerand['lags']=range(1,len(a)+1)
    print('----time series: LB pure randomness test----')
    print(LB_purerand)

# %% [markdown]
# ## 開始分析

# %%
##read data
dfname='table3.21'
y=pd.read_csv('%s.csv'%dfname,header=None)
y.iloc[:,0]=y.iloc[:,0].astype('float')
y=y.values[:,0]
drawts(y,dfname)
purerandtest(y)
# Out:
# ----time series: LB pure randomness test----
#            LB    Pvalue  lags
# 0   10.175228  0.001423     1
# 1   15.710011  0.000388     2
# 2   19.779302  0.000189     3
# 3   23.398279  0.000105     4
# 4   26.314867  0.000078     5
# 5   29.872481  0.000042     6
# 6   31.642297  0.000047     7
# 7   31.755547  0.000103     8
# 8   33.953198  0.000091     9
# 9   36.293542  0.000075    10
# 10  37.641033  0.000090    11
# 11  38.579968  0.000123    12
# 12  38.580372  0.000233    13
# 13  38.642928  0.000414    14
# 14  38.644923  0.000724    15
# 15  38.750764  0.001181    16
# 16  41.121919  0.000897    17
# 17  43.369263  0.000709    18
# 18  45.852373  0.000520    19
# 19  46.488299  0.000690    20
# 20  46.517763  0.001090    21
# 21  46.772098  0.001571    22
# 22  49.901492  0.000949    23
# 23  49.916026  0.001451    24
# 24  49.940678  0.002167    25
# 25  50.351186  0.002854    26
# 26  50.358449  0.004136    27
# 27  50.613550  0.005520    28
# 28  51.867789  0.005639    29
# 29  52.112644  0.007406    30
# 30  52.524849  0.009227    31
# 31  52.904296  0.011475    32
# 32  53.849022  0.012413    33
# 33  53.955252  0.016170    34
# 34  54.649078  0.018311    35
# D:\Anaconda\lib\site-packages\statsmodels\stats\diagnostic.py:531: FutureWarning: The default value of lags is changing.  After 0.12, this value will become min(10, nobs//5). Directly setlags to silence this warning.
#   warnings.warn("The default value of lags is changing.  After 0.12, "
# D:\Anaconda\lib\site-packages\statsmodels\stats\diagnostic.py:559: FutureWarning: The value returned will change to a single DataFrame after 0.12 is released.  Set return_df to True to use to return a DataFrame now.  Set return_df to False to silence this warning.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 參數估計

# %%
import statsmodels.tsa.api as smt
arma10=smt.ARMA(y,(0,2)).fit()
print('\n----fitting summary----')
print(arma10.summary())
print('sigma 2 of residual: %f'%arma10.sigma2)
# Out:
# ----fitting summary----
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   70
# Model:                     ARMA(0, 2)   Log Likelihood                -265.353
# Method:                       css-mle   S.D. of innovations             10.697
# Date:                Sun, 10 Oct 2021   AIC                            538.706
# Time:                        00:25:20   BIC                            547.700
# Sample:                             0   HQIC                           542.278
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         51.1695      1.252     40.883      0.000      48.716      53.623
# ma.L1.y       -0.3194      0.116     -2.754      0.006      -0.547      -0.092
# ma.L2.y        0.3019      0.123      2.448      0.014       0.060       0.544
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            0.5291           -1.7415j            1.8201           -0.2031
# MA.2            0.5291           +1.7415j            1.8201            0.2031
# -----------------------------------------------------------------------------
# sigma 2 of residual: 114.435762

# %% [markdown]
# ## 模型顯著性檢驗

# %%
resid=arma10.resid
print('\n----residual pure randomness test')
purerandtest(resid)
# Out:
# ----residual pure randomness test
# ----time series: LB pure randomness test----
#            LB    Pvalue  lags
# 0    0.109496  0.740719     1
# 1    0.182639  0.912726     2
# 2    1.397120  0.706210     3
# 3    1.407588  0.842875     4
# 4    1.992602  0.850168     5
# 5    2.321882  0.887845     6
# 6    2.498349  0.927221     7
# 7    2.782744  0.947243     8
# 8    2.951245  0.966197     9
# 9    3.562736  0.964925    10
# 10   4.392308  0.957006    11
# 11   4.480462  0.973126    12
# 12   5.242404  0.969462    13
# 13   5.524031  0.977102    14
# 14   6.243747  0.975356    15
# 15   9.304154  0.900361    16
# 16  10.271145  0.891856    17
# 17  10.767571  0.903958    18
# 18  10.949160  0.925537    19
# 19  11.065750  0.944500    20
# 20  11.283375  0.956980    21
# 21  11.882489  0.959759    22
# 22  12.286144  0.965816    23
# 23  13.641215  0.954343    24
# 24  13.675957  0.967091    25
# 25  13.847198  0.974959    26
# 26  13.901305  0.982200    27
# 27  15.000644  0.978429    28
# 28  15.382566  0.981799    29
# 29  15.383613  0.987384    30
# 30  15.393469  0.991337    31
# 31  15.771621  0.992749    32
# 32  16.185219  0.993809    33
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\stats\diagnostic.py:494: FutureWarning: The default value of lags is changing.  After 0.12, this value will become min(10, nobs//5). Directly setlags to silence this warning.
#   warnings.warn("The default value of lags is changing.  After 0.12, "
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\stats\diagnostic.py:524: FutureWarning: The value returned will change to a single DataFrame after 0.12 is released.  Set return_df to True to use to return a DataFrame now.  Set return_df to False to silence this warning.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 模型優化ARMA(1,0)

# %%
import statsmodels.tsa.api as smt
arma10=smt.ARMA(y,(1,0)).fit()
print('\n----fitting summary----')
print(arma10.summary())
print('sigma 2 of residual: %f'%arma10.sigma2)

resid=arma10.resid
print('\n----residual pure randomness test')
purerandtest(resid)
# Out:
# ----fitting summary----
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   70
# Model:                     ARMA(1, 0)   Log Likelihood                -265.979
# Method:                       css-mle   S.D. of innovations             10.798
# Date:                Sun, 10 Oct 2021   AIC                            537.958
# Time:                        00:33:21   BIC                            544.703
# Sample:                             0   HQIC                           540.637
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         51.2658      0.914     56.106      0.000      49.475      53.057
# ar.L1.y       -0.4191      0.113     -3.715      0.000      -0.640      -0.198
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.3862           +0.0000j            2.3862            0.5000
# -----------------------------------------------------------------------------
# sigma 2 of residual: 116.601478
#
# ----residual pure randomness test
# ----time series: LB pure randomness test----
#            LB    Pvalue  lags
# 0    0.319447  0.571940     1
# 1    2.143900  0.342340     2
# 2    2.289929  0.514453     3
# 3    2.441744  0.655097     4
# 4    3.592215  0.609483     5
# 5    4.552439  0.602355     6
# 6    4.572241  0.712002     7
# 7    4.831249  0.775451     8
# 8    4.911578  0.841947     9
# 9    5.639236  0.844608    10
# 10   6.866946  0.809754    11
# 11   6.926970  0.862402    12
# 12   9.107316  0.764791    13
# 13   9.895481  0.769784    14
# 14  10.665708  0.775912    15
# 15  13.666140  0.623570    16
# 16  14.182717  0.654129    17
# 17  14.357029  0.705538    18
# 18  14.569402  0.749544    19
# 19  14.578406  0.800002    20
# 20  14.580729  0.843387    21
# 21  15.839570  0.823767    22
# 22  16.462658  0.834760    23
# 23  18.094523  0.798399    24
# 24  18.187854  0.834313    25
# 25  18.362143  0.862203    26
# 26  18.537356  0.886239    27
# 27  20.124300  0.859891    28
# 28  20.762812  0.867643    29
# 29  20.781048  0.894609    30
# 30  20.794325  0.917231    31
# 31  21.385897  0.922867    32
# 32  22.274927  0.921295    33
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\stats\diagnostic.py:494: FutureWarning: The default value of lags is changing.  After 0.12, this value will become min(10, nobs//5). Directly setlags to silence this warning.
#   warnings.warn("The default value of lags is changing.  After 0.12, "
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\stats\diagnostic.py:524: FutureWarning: The value returned will change to a single DataFrame after 0.12 is released.  Set return_df to True to use to return a DataFrame now.  Set return_df to False to silence this warning.
#   warnings.warn(msg, FutureWarning)
